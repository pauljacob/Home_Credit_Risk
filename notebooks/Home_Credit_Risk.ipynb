# %%
# Data Source: https://www.kaggle.com/competitions/home-credit-credit-risk-model-stability/data

# %%
#link python site packages folder
import sys
source_directory = "/Users/pauljacob/Library/Python/3.9/lib/python/site-packages"
sys.path.append(source_directory)

# %%
import pandas as pd

def preview_df(df):
    """Of this DataFrame, prints the row and column count and then returns the concatenated first 5 and last % rows.

    Args:
        df (DataFrame): This pandas DataFrame object.
    Returns:
        df (DataFrame): The concatenated first 5 and last 5 rows of this pandas DataFrame.
    """
    if df.shape[0] > 9:
        print(df.shape)
        return pd.DataFrame(pd.concat([df.head(5), df.tail(5)]))
    else:
        return df

# %%
import pandas as pd
import os

# %%
filename = 'train_credit_bureau_a_1_0.csv'
relative_filename_path = os.path.join('..', 'data', 'raw', 'csv_files', 'train', filename)
df = pd.read_csv(relative_filename_path)
preview_df(df)
# Out:
# /var/folders/77/y4hv4_s9751293nzv4yrfrtm0000gn/T/ipykernel_48660/2203221005.py:3: DtypeWarning: Columns (11,12,14,30,44,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(relative_filename_path)
# (4108212, 79)
#          case_id  annualeffectiverate_199L  annualeffectiverate_63L  \
# 0            388                       NaN                      NaN
# 1            388                       NaN                      NaN
# 2            388                       NaN                      NaN
# 3            388                       NaN                      NaN
# 4            388                       NaN                      NaN
# 4108207  2588481                       NaN                      NaN
# 4108208  2588481                       NaN                      NaN
# 4108209  2588481                       NaN                      NaN
# 4108210  2588481                       NaN                      NaN
# 4108211  2588481                       NaN                      NaN
#
#         classificationofcontr_13M classificationofcontr_400M contractst_545M  \
# 0                        ea6782cc                   a55475b1        7241344e
# 1                        4408ff0f                   a55475b1        7241344e
# 2                        a55475b1                   a55475b1        a55475b1
# 3                        a55475b1                   a55475b1        a55475b1
# 4                        a55475b1                   a55475b1        a55475b1
# 4108207                  a55475b1                   a55475b1        a55475b1
# 4108208                  a55475b1                   a55475b1        a55475b1
# 4108209                  a55475b1                   a55475b1        a55475b1
# 4108210                  a55475b1                   a55475b1        a55475b1
# 4108211                  a55475b1                   a55475b1        a55475b1
#
#         contractst_964M  contractsum_5085717L  credlmt_230A  credlmt_935A  \
# 0              a55475b1                   NaN           NaN      135806.0
# 1              a55475b1                   NaN           NaN           NaN
# 2              a55475b1                   NaN           NaN           NaN
# 3              a55475b1                   NaN           NaN           NaN
# 4              a55475b1                   NaN           NaN           NaN
# 4108207        a55475b1                   NaN           NaN           NaN
# 4108208        a55475b1                   NaN           NaN           NaN
# 4108209        a55475b1                   NaN           NaN           NaN
# 4108210        a55475b1                   NaN           NaN           NaN
# 4108211        a55475b1                   NaN           NaN           NaN
#
#          ... residualamount_488A residualamount_856A subjectrole_182M  \
# 0        ...                 NaN          114325.805         a55475b1
# 1        ...                 NaN                 NaN         ab3c25cf
# 2        ...                 NaN                 NaN         a55475b1
# 3        ...                 NaN                 NaN         a55475b1
# 4        ...                 NaN                 NaN         a55475b1
# 4108207  ...                 NaN                 NaN         a55475b1
# 4108208  ...                 NaN                 NaN         a55475b1
# 4108209  ...                 NaN                 NaN         a55475b1
# 4108210  ...                 NaN                 NaN         a55475b1
# 4108211  ...                 NaN                 NaN         a55475b1
#
#         subjectrole_93M totalamount_6A  totalamount_996A  \
# 0              a55475b1            NaN               NaN
# 1              ab3c25cf            NaN         268897.62
# 2              a55475b1            NaN               NaN
# 3              a55475b1            NaN               NaN
# 4              a55475b1            NaN               NaN
# 4108207        a55475b1            NaN               NaN
# 4108208        a55475b1            NaN               NaN
# 4108209        a55475b1            NaN               NaN
# 4108210        a55475b1            NaN               NaN
# 4108211        a55475b1            NaN               NaN
#
#          totaldebtoverduevalue_178A totaldebtoverduevalue_718A  \
# 0                               NaN                        NaN
# 1                               0.0                        0.0
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# 4108207                         NaN                        NaN
# 4108208                         NaN                        NaN
# 4108209                         NaN                        NaN
# 4108210                         NaN                        NaN
# 4108211                         NaN                        NaN
#
#          totaloutstanddebtvalue_39A  totaloutstanddebtvalue_668A
# 0                               NaN                          NaN
# 1                          374419.5                          0.0
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# 4108207                         NaN                          NaN
# 4108208                         NaN                          NaN
# 4108209                         NaN                          NaN
# 4108210                         NaN                          NaN
# 4108211                         NaN                          NaN
#
# [10 rows x 79 columns]

# %%
# import pyarrow.parquet as pq


# filename = 'train_credit_bureau_a_1_0.parquet'
# relative_filename_path = os.path.join('..', 'data', 'raw', 'parquet_files', 'train', filename)
# df_ = pq.read_table(relative_filename_path).to_pandas()

# preview_df(df_)
